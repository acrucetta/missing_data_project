# %%
import numpy as np
import pandas as pd
import sys  
sys.path.insert(0, '../utils')
import importlib

import cross_validation as cv
importlib.reload(cv)
import utils

# %%
bikey, bikeX = utils.read_in(utils.bike_file_path, "bike")

bikeresults0 = cv.cross_validation(bikeX, bikey, 60615, 35, ["instant", "dteday"], iters=10, obsp=.9)
bikeresults0
# Out:
# At mean, iteration 0, time: 1639073986.6861978
# At SVT, iteration 0, time: 1639073986.9709198
# At KNN, iteration 0, time: 1639074043.6467197
# At EM, iteration 0, time: 1639074229.2491114
# At LS, iteration 0, time: 1639074283.1451476
#          season   yr  mnth        hr   holiday   weekday  workingday  \
# 0      0.000000  0.0   0.0  0.000000  0.000000  1.000000    0.000000
# 1      0.000000  0.0   0.0  0.043478  0.000000  1.000000    0.680657
# 2      0.000000  0.0   0.0  0.086957  0.000000  1.000000    0.000000
# 3      0.500843  0.0   0.0  0.130435  0.000000  1.000000    0.000000
# 4      0.000000  0.0   0.0  0.173913  0.000000  1.000000    0.000000
# ...         ...  ...   ...       ...       ...       ...         ...
# 17374  0.500843  1.0   1.0  0.826087  0.028812  0.500705    1.000000
# 17375  0.000000  1.0   1.0  0.869565  0.000000  0.166667    1.000000
# 17376  0.000000  1.0   1.0  0.913043  0.000000  0.166667    1.000000
# ...

# %%
bikey, bikeX = utils.read_in(utils.bike_file_path, "bike")

bikeresults1 = cv.cross_validation(bikeX, bikey, 606, 35, ["instant", "dteday"], iters=10, obsp=.85)
bikeresults1
# Out:
# At mean, iteration 0, time: 1639077022.0031013
# At SVT, iteration 0, time: 1639077022.2594252
# At KNN, iteration 0, time: 1639077174.1483586
# At EM, iteration 0, time: 1639077466.6850646
# At LS, iteration 0, time: 1639077531.4837797
#         season        yr      mnth        hr  holiday   weekday  workingday  \
# 0      0.00000  0.000000  0.000000  0.000000      0.0  1.000000    0.682065
# 1      0.00000  0.000000  0.000000  0.043478      0.0  1.000000    0.000000
# 2      0.00000  0.000000  0.000000  0.086957      0.0  1.000000    0.000000
# 3      0.49973  0.499898  0.502681  0.130435      0.0  1.000000    0.000000
# 4      0.49973  0.000000  0.000000  0.173913      0.0  1.000000    0.000000
# ...        ...       ...       ...       ...      ...       ...         ...
# 17374  0.00000  1.000000  1.000000  0.502315      0.0  0.166667    1.000000
# 17375  0.00000  1.000000  1.000000  0.869565      0.0  0.166667    1.000000
# ...

# %%
bikey, bikeX = utils.read_in(utils.bike_file_path, "bike")

bikeresults2 = cv.cross_validation(bikeX, bikey, 60615, 35, ["instant", "dteday"], iters=10, obsp=.8)
bikeresults2
# Out:
# At mean, iteration 0, time: 1639081695.2070794
# At SVT, iteration 0, time: 1639081695.4721406
# At KNN, iteration 0, time: 1639081798.4492908
# At EM, iteration 0, time: 1639082194.8466146
# At LS, iteration 0, time: 1639082262.223064
#          season   yr      mnth        hr   holiday   weekday  workingday  \
# 0      0.000000  0.0  0.000000  0.501817  0.000000  1.000000    0.000000
# 1      0.000000  0.0  0.000000  0.043478  0.000000  1.000000    0.681375
# 2      0.000000  0.0  0.000000  0.086957  0.000000  1.000000    0.000000
# 3      0.500421  0.0  0.000000  0.130435  0.000000  1.000000    0.681375
# 4      0.000000  0.0  0.000000  0.173913  0.000000  1.000000    0.000000
# ...         ...  ...       ...       ...       ...       ...         ...
# 17374  0.500421  1.0  1.000000  0.826087  0.028955  0.501511    1.000000
# 17375  0.000000  1.0  1.000000  0.869565  0.000000  0.501511    1.000000
# 17376  0.000000  1.0  0.503424  0.913043  0.028955  0.166667    1.000000
# ...

# %%
bikey, bikeX = utils.read_in(utils.bike_file_path, "bike")
bikeresults3 = cv.cross_validation(bikeX, bikey, 607, 35, ["instant", "dteday"], iters=10, obsp=.7)
bikeresults3
# Out:
# At mean, iteration 0, time: 1639087695.2076304
# At SVT, iteration 0, time: 1639087695.4716153
# At KNN, iteration 0, time: 1639087891.5643327
# At EM, iteration 0, time: 1639088521.3477402
# At LS, iteration 0, time: 1639088637.4564912
#          season        yr     mnth        hr  holiday   weekday  workingday  \
# 0      0.503143  0.000000  0.00000  0.000000  0.00000  1.000000    0.000000
# 1      0.503143  0.000000  0.50345  0.043478  0.00000  1.000000    0.681882
# 2      0.503143  0.000000  0.00000  0.086957  0.00000  1.000000    0.000000
# 3      0.000000  0.000000  0.00000  0.130435  0.02894  1.000000    0.000000
# 4      0.000000  0.499754  0.00000  0.173913  0.00000  0.500177    0.000000
# ...         ...       ...      ...       ...      ...       ...         ...
# 17374  0.000000  1.000000  1.00000  0.500890  0.02894  0.166667    1.000000
# 17375  0.000000  1.000000  1.00000  0.869565  0.00000  0.166667    0.681882
# ...

# %%
bikey, bikeX = utils.read_in(utils.bike_file_path, "bike")
bikeresults4 = cv.cross_validation(bikeX, bikey, 608, 35, ["instant", "dteday"], iters=10, obsp=.6)
bikeresults4
# Out:
# At mean, iteration 0, time: 1639097515.776748
# At SVT, iteration 0, time: 1639097516.0714974
# At KNN, iteration 0, time: 1639097721.453237
# At EM, iteration 0, time: 1639098587.9688082
# At LS, iteration 0, time: 1639099257.6199274
#          season        yr      mnth        hr   holiday   weekday  workingday  \
# 0      0.499872  0.000000  0.000000  0.501466  0.025589  1.000000    0.000000
# 1      0.499872  0.000000  0.000000  0.501466  0.025589  1.000000    0.000000
# 2      0.000000  0.509072  0.000000  0.501466  0.000000  0.501865    0.684724
# 3      0.499872  0.509072  0.500322  0.130435  0.000000  0.501865    0.000000
# 4      0.499872  0.000000  0.000000  0.173913  0.000000  1.000000    0.684724
# ...         ...       ...       ...       ...       ...       ...         ...
# 17374  0.000000  1.000000  1.000000  0.826087  0.000000  0.501865    1.000000
# 17375  0.499872  0.509072  0.500322  0.501466  0.000000  0.501865    1.000000
# ...

# %%
bikey, bikeX = utils.read_in(utils.bike_file_path, "bike")
bikeresults5 = cv.cross_validation(bikeX, bikey, 608, 35, ["instant", "dteday"], iters=10, obsp=.5)
bikeresults5

# %%
results0_df = pd.DataFrame(bikeresults0)
results0_df.to_csv('../data/bike-ninety.csv')
results2_df = pd.DataFrame(bikeresults2)
results2_df.to_csv('../data/bike-eighty.csv')
results3_df = pd.DataFrame(bikeresults3)
results3_df.to_csv('../data/bike-seventy.csv')
