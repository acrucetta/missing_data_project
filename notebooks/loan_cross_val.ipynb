# %% [markdown]
# ### Loan Dataset Cross-Validation

# %%
# %cd /Users/andrescrucettanieto/Documents/GitHub/notebooks
# Out:
# [Errno 2] No such file or directory: '/Users/andrescrucettanieto/Documents/GitHub/notebooks'
# /Users/andrescrucettanieto/Documents/GitHub/missing_data_project

# %%
import numpy as np
import pandas as pd
import sys  
sys.path.insert(0, '../utils')
import cross_validation as cv
import utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/_y/rh14dq4163g6bmcj4knv4kzw0000gn/T/ipykernel_5574/2107872423.py in <module>
#       3 import sys
#       4 sys.path.insert(0, '../utils')
# ----> 5 import cross_validation as cv
#       6 import utils
#
# ModuleNotFoundError: No module named 'cross_validation'

# %%
loany, loanx = utils.read_in('data/loan_default_data/Training Data.csv','Loan')

loan_results = utils.cross_validation(loanx, loany, 60615, ["instant", "dteday"], iters=10)
# bikeresults

# %%
loanx
# Out:
#             Id   Income  Age  Experience Married/Single House_Ownership  \
# 0            1  1303834   23           3         single          rented
# 1            2  7574516   40          10         single          rented
# 2            3  3991815   66           4        married          rented
# 3            4  6256451   41           2         single          rented
# 4            5  5768871   47          11         single          rented
# ...        ...      ...  ...         ...            ...             ...
# 251995  251996  8154883   43          13         single          rented
# 251996  251997  2843572   26          10         single          rented
# 251997  251998  4522448   46           7         single          rented
# 251998  251999  6507128   45           0         single          rented
# 251999  252000  9070230   70          17         single          rented
#
#        Car_Ownership           Profession                 CITY  \
# ...
